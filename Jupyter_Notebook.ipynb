# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Introduction to Jupyter

# %% [markdown]
# # This is my first Jupyter Notebook,where I'm learning to work with its features and workflow.

# %% [markdown]
# # Objectives:
# # 1. To get familiar with basic features of Jupyter Noteeboks.
# # 2. To Learn how to write and run simple codes.

# %% [markdown]
# # Major Data Science languages are as follows:
# # 1. Python
# # 2. R
# # 3. SQL
# # 4. Julia
# # 5. Scala

# %% [markdown]
# # Widely used Data Science Libraries:
# # 1. In Python- Numpy,Pandas,Matplotlib,TenserFlow,Scikit-learn etc.
# # 2. In R-dplyr,ggplot2,tidyr etc.
# # 3. In Big Data- ApacheSpark, Dask

# %% [markdown]
# |DS Tool|Function|
# |-------|--------|
# |Python|General-purpose language used for data wrangling, modeling, automation,etc.|
# |R|Statistical computing language ideal for analysis, visualization,etc.|
# |Jupyter Notebook|Interactive environment for writing code|
# |NumPy|Fast numerical computing backbone for arrays,matrices,and math operations|
# |Pandas|Library for handling structured data|
# |TensorFlow|Deep-learning framework for building and training neural networks at scale|
# |Apache Spark|Distributed computing engine for processing massive datasets efficiently|
# |Tableau|Visualization platform for turning raw data to dashboards|

# %% [markdown]
# # Following are a few basic arithmetic operations such as addition, subtraction, multiplication, division: 3+5, 10-2, 4*6, 20/4

# %%
(18+2)*5
# Out:
# 100

# %%
minutes=90
hours=minutes/60
hours
# Out:
# 1.5

# %% [markdown]
# # Author: Pragya
